# %%
import pandas as pd
import sqlite3 as sql
import numpy as np

# %%
sql.sqlite_version
# Out:
# '3.39.3'

# %%
database = "earth_quake_damage.db"
con = sql.connect(database)

# %%
query = '''SELECT * FROM NepalEarhquakeDamage2015 WHERE district_id == 12'''

# %%
df = pd.read_sql_query(query, con)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39352 entries, 0 to 39351
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   building_id             39352 non-null  float64
#  1   district_id             39352 non-null  int64
#  2   count_floors_pre_eq     39352 non-null  int64
#  3   count_floors_post_eq    39352 non-null  int64
#  4   age_building            39352 non-null  int64
#  5   plinth_area_sq_ft       39352 non-null  int64
#  6   height_ft_pre_eq        39352 non-null  int64
#  7   height_ft_post_eq       39352 non-null  int64
#  8   land_surface_condition  39352 non-null  object
#  9   foundation_type         39352 non-null  object
#  10  roof_type               39352 non-null  object
#  11  ground_floor_type       39352 non-null  object
#  12  other_floor_type        39352 non-null  object
#  13  position                39352 non-null  object
# ...

# %%
df["building_ids"] = np.ceil(df["building_id"] / 1e6)
df.head()
# Out:
#     building_id  district_id  count_floors_pre_eq  count_floors_post_eq  \
# 0  1.201010e+11           12                    1                     1
# 1  1.201010e+11           12                    1                     1
# 2  1.201010e+11           12                    1                     1
# 3  1.201010e+11           12                    1                     1
# 4  1.201010e+11           12                    1                     1
#
#    age_building  plinth_area_sq_ft  height_ft_pre_eq  height_ft_post_eq  \
# 0             9                288                 9                  9
# 1            15                364                 9                  9
# 2            20                384                 9                  9
# 3            20                312                 9                  9
# 4            30                308                 9                  9
#
#   land_surface_condition foundation_type                 roof_type  \
# ...

# %%
df["district_id"].unique()
# Out:
# array([12, 20, 21, 22, 23, 24, 28, 29, 30, 31, 36], dtype=int64)

# %%
mask = df["district_id"] == 24
df[mask].shape
# Out:
# (98019, 17)
